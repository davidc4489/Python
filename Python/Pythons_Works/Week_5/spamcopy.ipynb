# %%
from typing import Set
import re

def tokenize(text):
    text = text.lower()
    all_words = re.findall("[a-z0-9']+", text)
    return set(all_words)

tokenize("Banana apPle Orange APPle")
# Out:
# {'apple', 'banana', 'orange'}

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn import datasets
import pandas as pd

categories = ['alt.atheism', 'soc.religion.christian', 'comp.graphics', 'sci.med']
train_data = fetch_20newsgroups(subset='train', categories=categories, shuffle=True, random_state=42)
test_data = fetch_20newsgroups(subset='test', categories=categories, shuffle=True, random_state=42)
len(train_data.data),len(test_data.data)

dataset = fetch_20newsgroups(subset='all', categories=categories)

def tokenize(text):
    text = text.lower()
    all_words = re.findall("[a-z0-9']+", text)
    return set(all_words)
# Out:
# 1502
# 2257
# [2 3 3 ... 2 0 2]
# 3759 documents
# 4 categories
# contenu de l'attribut target: array([2, 3, 3, ..., 2, 0, 2])
# contenu de l'attribut target_names: ['alt.atheism', 'comp.graphics', 'sci.med', 'soc.religion.christian']
# From: geb@cs.pitt.edu (Gordon Banks)
# Subject: Re: "CAN'T BREATHE"
# Article-I.D.: pitt.19440
# Reply-To: geb@cs.pitt.edu (Gordon Banks)
# Organization: Univ. of Pittsburgh Computer Science
# Lines: 23
#
# In article <1993Mar29.204003.26952@tijc02.uucp> pjs269@tijc02.uucp (Paul Schmidt) writes:
# >I think it is important to verify all procedures with proper studies to
# >show their worthiness and risk.  I just read an interesting tidbit that
# >80% of the medical treatments are unproven and not based on scientific
# >fact.  For example, many treatments of prostate cancer are unproven and
# >the treatment may be more dangerous than the disease (according to the
# >article I read.)
#
# Where did you read this?  I don't think this is true.  I think most
# medical treatments are based on science, although it is difficult
# to prove anything with certitude.  It is true that there are some
# things that have just been found "to work", but we have no good
# explanation for why.  But almost everything does have a scientific
# rationale.  The most common treatment for prostate cancer is
# probably hormone therapy.  It has been "proven" to work.  So have
# radiation and chemotherapy.  What treatments did the article say
# are not proven?
#
# --
# ----------------------------------------------------------------------------
# Gordon Banks  N3JXP      | "Skepticism is the chastity of the intellect, and
# geb@cadre.dsl.pitt.edu   |  it is shameful to surrender it too soon."
# ----------------------------------------------------------------------------
#
# 2
# 3759
# From: brian@ucsd.edu (Brian Kantor)
# Subject: Re: HELP for Kidney Stones ..............
# Organization: The Avant-Garde of the Now, Ltd.
# Lines: 12
# NNTP-Posting-Host: ucsd.edu
#
# As I recall from my bout with kidney stones, there isn't any
# medication that can do anything about them except relieve the pain.
#
# Either they pass, or they have to be broken up with sound, or they have
# to be extracted surgically.
#
# When I was in, the X-ray tech happened to mention that she'd had kidney
# stones and children, and the childbirth hurt less.
#
# Demerol worked, although I nearly got arrested on my way home when I barfed
# all over the police car parked just outside the ER.
# 	- Brian

# %%
from typing import List, Tuple, Dict, Iterable
import math
from collections import defaultdict
import numpy as np

class NaiveBayesClassifier:
    def __init__(self, k = 0.5):
        self.k = k
        self.tokens = set()
        self.token_atheism_counts = {}
        self.token_graphics_counts = {}
        self.token_med_counts = {}
        self.token_christian_counts = {}
        self.atheism_messages = self.graphics_messages = self.med_messages = self.christian_messages = 0

    def train(self, dataset):
        for i in range(len(dataset.data)):
            if dataset.target[i] == 0:
                self.atheism_messages += 1
            elif dataset.target[i] == 1:
                self.graphics_messages += 1
            elif dataset.target[i] == 2:
                self.med_messages += 1
            elif dataset.target[i] == 3:
                self.christian_messages += 1

            for token in tokenize(dataset.data[i]):
                self.tokens.add(token)
                if dataset.target[i] == 0 and token not in self.token_atheism_counts:
                 self.token_atheism_counts[token] = 1
                elif dataset.target[i] == 0 and token in self.token_atheism_counts:
                 self.token_atheism_counts[token] += 1
                elif dataset.target[i] == 1 and token not in self.token_graphics_counts:
                  self.token_graphics_counts[token] = 1
                elif dataset.target[i] == 1 and token in self.token_graphics_counts:
                  self.token_graphics_counts[token] += 1
                elif dataset.target[i] == 2 and token not in self.token_med_counts:
                  self.token_med_counts[token] = 1
                elif dataset.target[i] == 2 and token in self.token_med_counts:
                  self.token_med_counts[token] += 1
                elif dataset.target[i] == 3 and token not in self.token_christian_counts:
                  self.token_christian_counts[token] = 1
                elif dataset.target[i] == 3 and token in self.token_christian_counts:
                  self.token_christian_counts[token] += 1

    def _probabilities(self, token):
        if token in self.token_atheism_counts:
            atheism = self.token_atheism_counts[token]
        else:
           atheism = 0
        if token in self.token_graphics_counts:
            graphics = self.token_graphics_counts[token]
        else:
           graphics = 0
        if token in self.token_med_counts:
            med = self.token_med_counts[token]
        else:
           med = 0
        if token in self.token_christian_counts:
            christian = self.token_christian_counts[token]
        else:
           christian = 0

        p_token_atheism = (atheism + self.k) / (self.atheism_messages + 2*self.k)
        p_token_graphics = (graphics + self.k) / (self.graphics_messages + 2*self.k)
        p_token_med = (med + self.k) / (self.med_messages + 2*self.k)
        p_token_christian = (christian + self.k) / (self.christian_messages + 2*self.k)
        return p_token_atheism, p_token_graphics, p_token_med, p_token_christian
    
    def predict(self, text):
        target=[]
        for i in range(len(text.data)):
           target.append(text.target[i])
        
        list_of_classes = []
        list_prop = []
        for i in range(len(text.data)):
            text_tokens = tokenize(text.data[i])
            log_prob_if_atheism = log_prob_if_graphics = log_prob_if_med = log_prob_if_christian = 0.0

            for token in text_tokens:
                    prob_if_atheism, prob_if_graphics, prob_if_med, prob_if_christian = self._probabilities(token)
                    log_prob_if_atheism += math.log(prob_if_atheism)
                    log_prob_if_graphics += math.log(prob_if_graphics)
                    log_prob_if_med += math.log(prob_if_med)
                    log_prob_if_christian += math.log(prob_if_christian)

            """for token in self.tokens:
                prob_if_atheism, prob_if_graphics, prob_if_med, prob_if_christian = self._probabilities(token)

                if token in text_tokens:
                    log_prob_if_atheism += math.log(prob_if_atheism)
                    log_prob_if_graphics += math.log(prob_if_graphics)
                    log_prob_if_med += math.log(prob_if_med)
                    log_prob_if_christian += math.log(prob_if_christian)

                else:
                   pass """
            
            """ else:
                    log_prob_if_atheism += math.log(1.0 - prob_if_atheism)
                    log_prob_if_graphics += math.log(1.0 - prob_if_graphics)
                    log_prob_if_med += math.log(1.0 - prob_if_med)
                    log_prob_if_christian += math.log(1.0 - prob_if_christian) """

            """             prob_if_atheism = math.exp(log_prob_if_atheism)
            prob_if_graphics = math.exp(log_prob_if_graphics)
            prob_if_med = math.exp(log_prob_if_med)
            prob_if_christian = math.exp(log_prob_if_christian) """

            """             list_prop.append(prob_if_atheism)
            list_prop.append(prob_if_graphics)
            list_prop.append(prob_if_med)
            list_prop.append(prob_if_christian) """

            max_prop = max(log_prob_if_atheism,log_prob_if_graphics,log_prob_if_med,log_prob_if_christian)

            if max_prop == prob_if_atheism:
               list_of_classes.append(0)
            if max_prop == prob_if_graphics:
               list_of_classes.append(1)
            if max_prop == prob_if_med:
               list_of_classes.append(2)
            if max_prop == prob_if_christian:
               list_of_classes.append(3)

        print(list_of_classes)

        """             if (prob_if_atheism+prob_if_graphics+prob_if_med+prob_if_christian) == 0.0:
                end_prob_if_atheism =  end_prob_if_graphics = end_prob_if_med = end_prob_if_christian = 0
            else: 
                end_prob_if_atheism = prob_if_atheism/(prob_if_atheism+prob_if_graphics+prob_if_med+prob_if_christian)
                end_prob_if_graphics = prob_if_graphics/(prob_if_atheism+prob_if_graphics+prob_if_med+prob_if_christian)
                end_prob_if_med = prob_if_med/(prob_if_atheism+prob_if_graphics+prob_if_med+prob_if_christian)
                end_prob_if_christian = prob_if_christian/(prob_if_atheism+prob_if_graphics+prob_if_med+prob_if_christian)

            if max(end_prob_if_atheism,end_prob_if_graphics,end_prob_if_med,end_prob_if_christian)==end_prob_if_atheism:
                list_of_classes.append(0)
            elif max(end_prob_if_atheism,end_prob_if_graphics,end_prob_if_med,end_prob_if_christian)==end_prob_if_graphics:
                list_of_classes.append(1)
            elif max(end_prob_if_atheism,end_prob_if_graphics,end_prob_if_med,end_prob_if_christian)==end_prob_if_med:
                list_of_classes.append(2)
            elif max(end_prob_if_atheism,end_prob_if_graphics,end_prob_if_med,end_prob_if_christian)==end_prob_if_christian:
                list_of_classes.append(3) """
        
        list_of_classes = np.array(list_of_classes)
        target = np.array(target)
        return list_of_classes, target
        
model = NaiveBayesClassifier(k=0.5)
model.train(train_data)
print(len(model.tokens))
print(model.christian_messages)
print(model.med_messages)
print(model.graphics_messages)
print(model.atheism_messages)
print(model.token_atheism_counts)
print(model.token_graphics_counts)
print(model.token_med_counts)
print(model.token_christian_counts)
testing = model.predict(test_data)
arr1=testing[0]
arr2=testing[1]
print(arr1)
# Out:
# 36374
# 599
# 594
# 584
# 480
# {'blue': 5, 'catholic': 14, 'statements': 28, 'attribute': 4, 'seem': 68, 'are': 322, 'trw': 24, 'from': 480, 'presence': 4, "don't": 216, 'god': 169, 'ability': 18, 'all': 234, 'am': 92, 'playing': 6, 'left': 25, 'trying': 46, 'scenario': 4, 'batman': 25, 'here': 118, 'especially': 27, 'bolsters': 1, 'fall': 24, 'way': 120, 'alternatives': 10, 'can': 217, 'beings': 16, 'jbrown': 24, 'benedikt': 43, 'doing': 41, 'outcome': 1, 'sentences': 3, 'unfortunately': 17, 'object': 13, 'weak': 26, 'contradictions': 10, 'possibility': 21, 'imagine': 23, '114': 1, 'people': 195, 'power': 26, 'fact': 83, 'ubiquitous': 1, 'fiction': 7, 'following': 28, 'not': 342, 'at': 220, 'have': 316, 'ungodliness': 1, 'nature': 39, 'events': 18, 'less': 37, 'omnipotent': 8, 'avoiding': 2, 'bs': 37, 'necessary': 27, 'take': 87, 'choose': 16, 'simply': 48, 'for': 337, 'would': 207, 'article': 294, 'known': 41, 'easily': 14, 'imply': 21, 'arguing': 12, 'holy': 17, 'defined': 31, 'might': 81, 'occur': 12, 'long': 70, 'rz': 37, 'is': 417, 'they': 221, 'i': 408, 'just': 164, 'description': 13, 'definitions': 15, 'destroys': 2, 'want': 74, "that's": 80, 'as': 277, 'contradiction': 17, 'itself': 34, 'credibility': 5, "can't": 77, 'omniscient': 11, 'has': 173, 'consistent': 16, 'sin': 8, '823': 2, 'emergence': 1, 'away': 52, 'restrains': 1, 'another': 70, 'letting': 7, 'understand': 61, '091139': 2, 'pet': 2, 'may': 84, 'tu': 37, 'must': 118, 'believed': 17, 'will': 164, 'between': 48, 'since': 82, 'the': 472, 'definitional': 1, 'university': 164, 'independently': 8, 'dbstu1': 36, 'perhaps': 56, 'says': 63, 'follows': 22, 'my': 188, 'truly': 14, 'anything': 74, 'describes': 7, 'completely': 21, "being's": 1, 'biblical': 17, 'reading': 37, 'specifically': 16, 'case': 90, 'knowledge': 32, 'atheism': 92, 'which': 181, 'now': 111, 'use': 60, 'argument': 60, 'logically': 17, 'self': 26, 'evil': 25, 'when': 139, 'know': 154, 'moral': 70, 'place': 28, 'disagree': 13, 'believe': 108, 'such': 128, 'mind': 43, 'than': 174, 'creatures': 4, "i'm": 130, 'terms': 21, "jehovah's": 13, 'while': 55, 'i3150101': 36, 'unresolvable': 1, 'bible': 64, 'true': 79, 'it': 380, 'technical': 27, 'writes': 390, 'creating': 5, 'feel': 31, 'in': 454, 'say': 174, 'yes': 63, 'exists': 33, 'causing': 3, 'allows': 11, 'created': 35, 'shows': 15, 'give': 63, 'could': 155, 'speculation': 3, 'his': 122, 'conscious': 8, 'choices': 9, 'like': 155, 'to': 445, 'ordinarily': 1, 'even': 137, 'some': 206, 'any': 182, 'least': 58, 'or': 281, 'them': 128, 'com': 229, 'your': 233, 'certain': 40, 'think': 177, 'evidence': 67, 're': 456, 'subject': 480, 'was': 263, 'obeying': 3, 'other': 164, 'these': 112, 'free': 51, 'sweeping': 6, 'what': 264, 'determination': 4, 'who': 189, 'similar': 37, 'those': 108, 'that': 421, 'clearly': 23, 'about': 224, 'by': 249, 'taking': 16, 'conceivable': 3, 'happen': 17, 'loving': 4, 'already': 27, 'idea': 49, 'play': 12, 'allow': 20, 'but': 300, 'deletion': 17, 'then': 163, 'foot': 8, 'religion': 87, 'opinion': 37, 'visit': 13, 'allowing': 6, 'best': 35, 'there': 227, 'exactly': 35, 'mean': 85, 'course': 69, 'implemented': 7, 'making': 38, 'why': 153, 'fixed': 2, 'something': 117, 'organization': 453, 'atheist': 63, 'prevented': 4, 'advance': 4, 'indicates': 8, 'gives': 10, 'worship': 8, 'science': 47, 'well': 141, 'germany': 40, "didn't": 58, 'do': 235, 'nevertheless': 7, 'cannot': 75, 'note': 35, 'greater': 16, 'tims': 4, 'mouth': 12, 'no': 220, 'unipolar': 1, 'view': 43, 'used': 49, 'this': 326, 'games': 2, 'time': 127, 'james': 29, 'game': 11, 'first': 83, 'said': 133, 'coming': 12, 'unicorns': 10, 'whose': 20, 'up': 134, 'seems': 88, 'fair': 11, 'lucifer': 4, 'him': 80, 'therefore': 64, 'claims': 29, 'appreciate': 6, 'how': 156, 'one': 249, 'and': 429, 'witnesses': 17, 'we': 214, 'make': 104, 'does': 150, 'nothing': 76, 'premise': 10, 'amount': 13, 'he': 147, 'himself': 29, 'a': 439, 'possible': 58, 'its': 72, 'definition': 41, 'absence': 10, 'so': 259, 'before': 70, 'done ...
# {'collier': 1, 'img': 3, 'into': 76, '0hb': 1, 'p': 43, 'does': 145, 'sd345': 1, 'anyone': 155, 'organization': 560, 'city': 12, 'a': 494, 'way': 79, 'is': 399, 'converting': 5, 'format': 59, 'same': 65, 'hp': 16, 'standard': 28, 'to': 503, 'like': 159, 'group': 52, 'would': 189, 'x3769': 1, 'also': 110, 'thanks': 186, 'programmer': 17, 'advance': 60, 'hampton': 1, 'hpgl': 3, 'email': 83, 'please': 129, 'the': 519, 'images': 62, 'michael': 25, 'any': 254, 'university': 265, 'convert': 35, 'nntp': 272, 'pc': 46, 'utility': 13, 'from': 584, 'know': 176, 'files': 93, 'computer': 117, 'tel': 22, 'london': 4, 'pd': 17, 'tga': 13, 'tif': 2, '8565': 1, 'ec1v': 1, 'plotter': 4, 'in': 448, 'this': 299, 'host': 275, '14': 31, '8000': 2, 'unit': 13, 'of': 488, 'correct': 22, 'application': 20, '071': 1, 'iii': 3, 'uk': 57, 'lines': 584, '477': 1, 'subject': 584, 'posting': 288, 'response': 11, 'fax': 57, 'do': 174, 'good': 98, 'laserjet': 3, 'm': 52, 'ac': 58, 'we': 70, 'else': 46, 'rejected': 1, 'up': 85, 'ani': 1, 'human': 21, 'edu': 319, 'i': 473, 'solve': 7, 'notation': 2, 'individual': 9, 'curve': 13, 'some': 164, 'divine': 5, 'segments': 3, 'as': 180, 'or': 281, 'problem': 62, 'split': 17, 'loop': 6, 'rendered': 4, 'how': 122, 'has': 140, 'mapping': 11, 'thiss': 1, 'uv': 1, 'ms': 37, 'b': 57, 'bounded': 3, 'help': 129, 'set': 39, 'get': 123, 'by': 160, 'can': 230, 'cells': 2, 'done': 25, 'trimming': 2, 'inside': 13, '2d': 19, 'made': 27, 'my': 164, 'then': 83, 'background': 10, 'doing': 34, 'there': 227, "'gurus'": 1, 'hi': 86, 'dept': 46, 'splitting': 3, 'along': 16, 'somewhere': 10, 'which': 140, 'irritated': 1, 'deglurkar': 1, 'appreciated': 55, 'math': 14, 'patch': 6, 'area': 12, 'domain': 21, 'have': 304, 'mesh': 5, 'body': 8, 'wholly': 1, '28': 15, 'output': 23, 'cool': 6, 'stay': 6, 'had': 54, 'sciences': 17, 'e': 109, 'smaller': 5, 'kentucky': 3, 'for': 439, 'it': 365, '3d': 73, 'algo': 5, 'if': 250, 'region': 3, 'sake': 3, 'cell': 2, 'aniruddha': 1, 'rectangular': 8, 'hope': 32, 'bezier': 11, 'trivially': 1, 'me': 195, 'uky': 5, 'be': 280, 'whole': 15, '15': 51, 'signal': 8, 'project': 28, 'display': 42, 'intensity': 6, 'umd': 1, 'monitor': 14, 'are': 227, 'soomro': 1, '05': 5, 'your': 95, 'certain': 9, 'college': 26, 'linear': 10, 'am': 149, 'law': 3, 'digitizing': 5, 'these': 72, 'other': 121, 'and': 450, 'eng': 10, 'amjad': 1, 'wam': 1, 'park': 7, 'example': 25, '93': 16, 'glue': 1, 'that': 313, 'brightness': 3, 'before': 39, 'levels': 8, 'grey': 8, 'follow': 5, 'displaying': 14, 'program': 109, 'non': 35, 'ntsc': 8, 'filter': 8, 'signals': 2, 'ccs': 2, 'tv': 7, 'center': 46, 'linearities': 1, 'sometimes': 5, 'expires': 4, 'not': 217, 'at': 196, 'science': 56, 'corrected': 4, 'errrors': 1, 'with': 254, 'much': 74, 'on': 314, 'words': 17, 'distribution': 108, 'coded': 4, 'maryland': 6, 'video': 55, 'circuitry': 1, 'tubes': 1, 'encoding': 3, 'u': 42, '256': 36, 'known': 19, 'usa': 34, 'c': 115, '22': 31, 'supposed': 2, 'correction': 2, 'gamma': 2, 'appear': 8, 'said': 22, 'hc': 2, 'seconds': 7, 'ti': 4, 'years': 26, '16': 58, 'birmingham': 8, '10': 52, 'mac': 44, 'al': 13, 'timing': 5, '2213': 4, 'them': 74, 'exposure': 3, 'com': 166, 'all': 151, 're': 292, 'more': 108, 'using': 87, 'level': 23, 'hall': 9, 'bit': 77, 'photos': 5, 'drastically': 1, '1170': 4, '128': 13, 'slices': 4, 'friend': 10, '115a': 4, 'synchronized': 2, 'about': 183, '934': 4, 'but': 260, 'plus': 13, 'method': 27, 'total': 5, 'c51c4r': 1, 'few': 52, '205': 5, '2': 140, 'station': 14, 'gray': 12, 'why': 33, 'you': 270, 'reduces': 2, 'btg': 1, '60hz': 2, 'screen': 46, 'campbell': 6, '1': 198, '4': 89, '35294': 4, 'csc': 6, 'out': 163, '64': 13, 'ago': 17, "didn't": 22, 'cis': 12, 'sloan': 6, 'create': 31, 'requires': 19, 'precision': 7, 'information': 85, 'no': 122, '8': 70, 'kenneth': 10, 'writes': 194, 'article': 174, 'image': 104, 'alabama': 6, 'preparation': 1, 'took': 14, 'rowlands': 2, 'time': 87, '5473': 4, 'jon': 8, 'uab': 5, '32': 25, 'exploit ...
# {'advice': 36, 'couple': 37, 'into': 94, 'food': 81, 'where': 101, 'spots': 7, 'father': 4, 'cap': 2, "he's": 15, 'bury': 2, 'thing': 71, 'could': 123, 'his': 98, "i've": 83, 'keeping': 5, 'dip': 1, 'teenage': 2, 'is': 530, 'teenager': 2, 'they': 229, 'simple': 26, 'fast': 11, 'i': 484, 'to': 557, 'hairline': 2, 'even': 121, 'him': 43, 'some': 237, 'however': 72, 'want': 73, 'are': 348, 'any': 266, 'skin': 31, 'rinse': 1, 'appearance': 4, "that's": 71, 'from': 594, 'as': 322, 'or': 335, "don't": 193, 'prescription': 14, 'because': 127, 'called': 70, 'around': 54, 'bathwater': 1, 'com': 307, 'wierd': 2, 'equipment': 8, 'overdose': 3, 'iodine': 1, 'cloths': 1, 'think': 153, 'has': 248, 'jacquelin': 5, 're': 441, 'subject': 594, 'communication': 11, 'was': 273, 'senstitive': 2, 'am': 133, 'these': 152, 'and': 546, 'one': 256, 'notice': 14, 'netcom': 32, 'hydrophilic': 1, 'becoming': 7, 'pchurch': 3, 'till': 4, 'heard': 51, "won't": 41, 'we': 154, 'tried': 30, 'washing': 2, 'make': 96, 'mousse': 1, 'pat': 5, 'nothing': 71, 'removed': 14, 'rinses': 1, 'infection': 30, 'cosmetic': 5, 'submerging': 1, 'dandruff': 2, 'he': 116, 'red': 15, 'money': 25, 'little': 57, 'who': 187, 'day': 68, 'a': 529, 'naturally': 11, 'same': 94, 'though': 65, 'control': 42, 'normal': 46, 'line': 21, 'help': 86, 'jackie': 2, 'softens': 1, 'nz': 8, 'get': 161, 'that': 478, 'so': 216, 'about': 267, 'off': 69, 'malady': 3, 'better': 64, 'taking': 51, 'wash': 7, 'will': 179, 'eating': 28, 'can': 282, 'afterwards': 6, 'the': 566, 'scaliness': 2, 'inclined': 2, 'probably': 79, 'idea': 52, 'incredible': 1, 'kid': 7, 'but': 347, 'nose': 23, 't': 31, "chemist's": 2, 'going': 61, 'clearasil': 2, '241': 15, 'dalacin': 2, 'chance': 16, 'prevent': 30, 'guest': 20, 'my': 287, 'ones': 25, 'of': 558, 'lucky': 5, "doctor's": 15, 'best': 72, 'shampoos': 2, 'there': 277, 'worse': 18, 'greasy': 5, 'tell': 52, 'misery': 2, 'bath': 6, 'acne': 3, 'makes': 40, 'getting': 58, 'eventually': 18, 'infections': 23, 'y': 6, 'days': 46, 'why': 99, 'chin': 3, 'really': 91, 'along': 21, 'pores': 1, 'churchill': 3, 'something': 103, 'which': 187, '57': 5, 'usual': 18, 'spotty': 3, 'escalate': 2, '21': 31, 'organization': 582, 'foods': 54, 'convinced': 8, 'people': 169, 'pimple': 1, 'condition': 33, 'ointment': 7, 'vitamin': 9, 'swell': 9, 'mineral': 3, 'oil': 7, 'spray': 4, 'break': 14, 'immediately': 12, 'not': 379, 'water': 26, 'leave': 9, 'at': 268, 'an': 279, 'gets': 33, 'services': 38, 'causes': 35, 'very': 148, 'have': 359, 'available': 50, 'sterilize': 1, 'meat': 17, 'their': 131, 'whiteheads': 1, 'anti': 25, 'know': 204, '408': 16, 'when': 173, 'body': 45, 'warm': 4, 'actrix': 6, 'down': 38, 'out': 178, '14': 36, 'with': 352, 'soaks': 1, 'usually': 63, 'black': 8, 'hidden': 5, "didn't": 32, 'on': 335, 'pharmacists': 2, 'lukewarm': 1, 'lines': 585, 'blackheads': 1, 'odd': 8, 'serious': 34, 'son': 11, 'do': 237, 'good': 133, 'put': 46, "neighbour's": 2, 'sort': 40, 'diet': 66, 'save': 5, 'had': 150, 'wary': 3, 'scalp': 3, 'goes': 15, 'cost': 18, 'more': 176, 'came': 29, 'dry': 16, 'industry': 18, 'treatment': 76, 'bought': 10, 'only': 153, 'no': 224, 'miserable': 3, 'o': 27, 'soften': 1, 'appropriate': 18, 'washes': 1, 'either': 44, 'disfiguring': 2, 'kids': 7, 'loves': 1, 'cause': 84, 'ok': 14, 'asked': 30, 'for': 425, 'it': 476, 'limp': 1, 'whitehead': 1, 'restaurants': 10, 'enough': 69, 'also': 175, 'used': 96, 'product': 24, 'alone': 14, 'selling': 6, 'writes': 344, 'pimples': 1, 'severe': 31, 'gen': 6, 'shall': 5, 'figure': 15, "it's": 120, 'frequent': 12, 'oilyness': 1, 'grease': 2, 'trouble': 19, 'under': 40, 'softened': 1, 'counter': 6, 'cradle': 2, 'in': 528, 'this': 408, 'prying': 1, 'say': 75, 'hair': 6, 'luck': 15, 'face': 24, 'belief': 6, 'me': 227, 'over': 73, 'aldridge': 6, 'causing': 26, 'oily': 3, '9760': 15, 'defect': 4, 'might': 88, 'pointers': 3, 'be': 379, 'blue': 18, 'types': 16, 'claimed': 4, 'blindsight': 3, 'edu': 416, 'common': 59, 'just': 172, 'computer':  ...
# {'san': 9, 'problems': 29, 'coming': 46, '15': 74, 'laugh': 5, 'reason': 98, 'could': 146, 'years': 84, 'yesterday': 4, 'up': 177, 'deal': 21, "i've": 81, '25': 40, 'is': 524, 'ignore': 10, 'call': 50, 'they': 317, 'ucsd': 7, 'edu': 465, 'i': 521, 'johnson': 16, 'to': 570, 'even': 182, 'offices': 1, 'company': 18, 'ups': 3, 'apply': 18, 'support': 28, 'some': 289, 'seem': 59, 'any': 261, 'are': 413, 'want': 116, 'after': 110, 'bothered': 5, 'insensitive': 3, 'computer': 35, 'from': 599, 'or': 342, 'anxiety': 2, 'miracle': 8, "don't": 228, 'problem': 103, 'because': 224, 'stop': 19, 'question': 175, 'your': 252, 'supportive': 4, 'due': 13, "can't": 75, 'dreaded': 2, 'how': 216, 'need': 108, 'has': 259, 're': 441, 'subject': 599, 'was': 349, 'more': 228, 'comes': 59, 'other': 238, 'these': 164, "i'll": 48, 'and': 548, 'notice': 13, 'attention': 14, 'ask': 84, 'one': 333, 'went': 24, 'preserving': 3, 'we': 327, 'left': 34, 'go': 115, 'trying': 69, 'number': 38, 'make': 140, 'accept': 71, 'does': 214, 'state': 67, 'sexual': 19, 'closing': 2, 'emotional': 10, 'what': 325, 'he': 300, 'personnel': 1, 'who': 345, 'priest': 17, 'a': 549, 'our': 204, 'lunch': 4, 'imbecile': 1, 'day': 91, 'may': 208, 'judgemental': 4, 'ignorant': 11, 'though': 93, 'post': 64, 'bring': 23, 'often': 60, 'that': 521, 'harrassed': 3, 'so': 287, 'about': 328, '11': 71, 'off': 62, 'will': 275, 'seriously': 16, 'email': 27, 'still': 97, 'can': 301, 'remains': 7, 'inconceivable': 3, 'the': 578, 'back': 77, 'done': 71, 'already': 36, 'insensitivity': 2, 'happen': 30, 'moderator': 24, 'hateful': 2, 'cse': 1, 'letter': 20, 'entire': 18, 'honest': 11, 'but': 419, 'through': 129, 'actions': 23, 'boss': 12, 'going': 81, 'higher': 11, 'perhaps': 63, 'happens': 20, 'maybe': 60, 'person': 84, 'working': 22, 'effectively': 8, 'my': 303, 'then': 205, 'normally': 15, 'signs': 12, 'doing': 68, 'of': 569, 'unclear': 4, 'come': 134, 'female': 12, 'jobs': 2, 'employee': 2, 'there': 312, 'comforting': 4, 'angry': 14, 'most': 154, 'seeing': 15, 'constant': 10, 'opinions': 59, 'broken': 17, 'turn': 24, 'been': 227, 'realized': 6, 'feelings': 15, 'posted': 21, 'husband': 18, 'dept': 28, 'building': 12, 'great': 78, 'fight': 7, 'privacy': 1, 'why': 173, 'you': 389, 'willing': 27, 'something': 134, 'being': 180, 'harrassment': 2, 'manager': 3, 'organization': 536, 'people': 286, 'healing': 4, 'did': 160, 'center': 15, 'enormous': 2, 'stress': 4, 'mr': 15, 'indulgence': 2, 'djohnson': 1, 'not': 455, 'cs': 60, 'prayers': 27, 'affect': 5, 'use': 95, 'check': 15, 'at': 313, 'an': 293, 'lot': 71, 'please': 75, 'enjoy': 6, 'hurt': 15, 'have': 432, 'ever': 78, 'sexually': 7, 'discuss': 21, 'their': 227, 'worthless': 5, 'know': 241, 'swap': 1, 'car': 5, 'well': 146, 'hustle': 1, 'keep': 51, "women's": 1, 'resource': 2, 'with': 387, 'out': 212, 'kind': 51, 'believe': 195, 'much': 144, 'than': 207, 'without': 111, "didn't": 70, 'on': 391, 'find': 137, 'bully': 2, 'lines': 599, 'action': 22, 'do': 323, 'good': 153, 'different': 81, 'wiser': 1, "i'm": 153, 'had': 174, '63': 7, 'paying': 2, 'employees': 2, 'realize': 37, 'someone': 85, 'single': 21, 'while': 89, 'darin': 1, 'agency': 2, 'ignored': 3, 'only': 239, 'various': 28, 'work': 81, 'no': 272, 'she': 50, 'engineering': 34, 'strife': 3, 'take': 99, 'should': 185, 'gross': 3, 'age': 26, 'cause': 30, '5': 84, 'for': 449, 'once': 57, 'it': 470, 'wonder': 16, 'u': 44, 'would': 336, 'also': 213, 'occasions': 7, 'tend': 19, "it's": 149, 'luxury': 2, 'hold': 47, 'c': 65, 'counted': 5, 'if': 397, 'feel': 59, 'playground': 1, 'bytes': 1, 'today': 62, 'department': 30, 'in': 556, 'this': 448, 'let': 71, 'etc': 88, 'harm': 8, 'latest': 9, 'companies': 1, 'diego': 4, 'esteem': 6, 'management': 5, 'hope': 59, 'me': 277, 'seven': 9, 'tolerated': 3, 'lawyer': 2, 'returned': 4, 'allows': 13, 'paster': 1, 'eight': 4, 'indeed': 48, 'be': 451, 'faculteit': 1, 'concerning': 16, 'nl': 3, 'role': 18, 'masja': 1, 'catholic': 67, 'zwart': 2, 'poland': 2, 'rijksuni ...
# []
# []

# %%
arr3 = arr1==arr2
testvalue = sum(arr3)/len(arr3)
testvalue
# Out:
# /tmp/ipykernel_8123/2379035652.py:1: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   arr3 = arr1==arr2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 2
#       1 arr3 = arr1==arr2
# ----> 2 testvalue = sum(arr3)/len(arr3)
#       3 testvalue
#
# TypeError: 'bool' object is not iterable
