# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import heapq as heap

# %%
file = '/home/mefathim/Documents/Python/maze.png'
file2 ='/home/mefathim/Documents/Python/maze2.jpg'
# file = '/home/mefathim-tech-25/Downloads/maze5.jpg'

# %%
img = cv2.imread(file) # read an image from a file using
cv2.circle(img,(5,220), 3, (255,0,0), -1) # add a circle at (5, 220)
cv2.circle(img, (25,5), 3, (0,0,255), -1) # add a circle at (25,5)
plt.figure(figsize=(7,7))
plt.imshow(img) # show the image
img = cv2.imread(file)
plt.show()

img2 = cv2.imread(file2) # read an image from a file using
cv2.circle(img2,(340,330), 3, (255,0,0), -1) # add a circle at (5, 220)
cv2.circle(img2, (25,330), 3, (0,0,255), -1) # add a circle at (25,5)
plt.figure(figsize=(7,7))
plt.imshow(img2) # show the image
img2 = cv2.imread(file2)
plt.show()

# %%
print(img.shape)
print(img2.shape)
# Out:
# (689, 564, 3)

# %%
# Your Code Should Be Here
matrice = cv2.imread('/home/mefathim/Documents/Python/maze.png')   # charge le fichier dans une matrice de pixels couleur
print(matrice.shape)              # affiche les dimensions de la matrice
print(matrice[0,0])               # accède à la valeur du premier pixel

# Python program for Dijkstra's single
# source shortest path algorithm. The program is
# for adjacency matrix representation of the graph
class Graph():
 
    def __init__(self, vertices):
        self.V = vertices
        self.graph = [[0 for column in range(vertices)]
                      for row in range(vertices)]
 
    def printSolution(self, dist):
        print("Vertex \t Distance from Source")
        for node in range(self.V):
            print(node, "\t\t", dist[node])
 
    # A utility function to find the vertex with
    # minimum distance value, from the set of vertices
    # not yet included in shortest path tree
    def minDistance(self, dist, sptSet):
 
        # Initialize minimum distance for next node
        min = 1e7
 
        # Search not nearest vertex not in the
        # shortest path tree
        for v in range(self.V):
            if dist[v] < min and sptSet[v] == False:
                min = dist[v]
                min_index = v
 
        return min_index
 
    # Function that implements Dijkstra's single source
    # shortest path algorithm for a graph represented
    # using adjacency matrix representation
    def dijkstra(self, src):
 
        dist = [1e7] * self.V
        dist[src] = 0
        sptSet = [False] * self.V
 
        for cout in range(self.V):
 
            # Pick the minimum distance vertex from
            # the set of vertices not yet processed.
            # u is always equal to src in first iteration
            u = self.minDistance(dist, sptSet)
 
            # Put the minimum distance vertex in the
            # shortest path tree
            sptSet[u] = True
 
            # Update dist value of the adjacent vertices
            # of the picked vertex only if the current
            # distance is greater than new distance and
            # the vertex in not in the shortest path tree
            for v in range(self.V):
                if (self.graph[u][v] > 0 and
                   sptSet[v] == False and
                   dist[v] > dist[u] + self.graph[u][v]):
                    dist[v] = dist[u] + self.graph[u][v]
 
        self.printSolution(dist)
 
# Driver program
g = Graph(225)
for i in range (225):
    for j in range(225):
        g.graph[i][j] = matrice[i,j]
 
g.dijkstra([0][0])





path = ...
# Out:
# (225, 225, 3)
# [61 61 61]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 76
#      73     for j in range(225):
#      74         g.graph[i][j] = matrice[i,j]
# ---> 76 g.dijkstra([0][0])
#      82 path = ...
#
# Cell In[51], line 63, in Graph.dijkstra(self, src)
#      58     # Update dist value of the adjacent vertices
#      59     # of the picked vertex only if the current
#      60     # distance is greater than new distance and
#      61     # the vertex in not in the shortest path tree
#      62     for v in range(self.V):
# ---> 63         if (self.graph[u][v] > 0 and
#      64            sptSet[v] == False and
#      65            dist[v] > dist[u] + self.graph[u][v]):
#      66             dist[v] = dist[u] + self.graph[u][v]
#      68 self.printSolution(dist)
#
# ...

# %%
def drawPath(img,path, thickness=1):
    '''path is a list of (x,y) tuples'''
    x0,y0=path[0]
    for vertex in path[1:]:
        x1,y1=vertex
        cv2.line(img,(y0,x0),(y1,x1),(255,0,0),thickness)
        x0,y0=vertex

# %%
drawPath(img,path)
plt.figure(figsize=(7,7))
plt.imshow(img) # show the image on the screen 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 drawPath(img,path)
#       2 plt.figure(figsize=(7,7))
#       3 plt.imshow(img) # show the image on the screen
#
# Cell In[48], line 3, in drawPath(img, path, thickness)
#       1 def drawPath(img,path, thickness=1):
#       2     '''path is a list of (x,y) tuples'''
# ----> 3     x0,y0=path[0]
#       4     for vertex in path[1:]:
#       5         x1,y1=vertex
#
# TypeError: 'ellipsis' object is not subscriptable
